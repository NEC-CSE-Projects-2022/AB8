# %% [markdown]
# # Importing the Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ['TORCH_USE_CUDA_DSA'] = "1"

# %%
import torch
from IPython.display import Image
import shutil
import os
from random import choice

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
ML_Model = []
precision = []
recall = []
mAP = []

#function to call for storing the results
def storeResults(model, a,b,c):
    ML_Model.append(model)
    precision.append(round(a, 3))
    recall.append(round(b, 3))
    mAP.append(round(c, 3))

# %%
# !mkdir v5
# Out:
# mkdir: cannot create directory ‘v5’: File exists

# %%
cd v5
# Out:
# /mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/v5

# %% [markdown]
# # **YoloV5**

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov5s6u.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/yolo/data.yaml", epochs=100, imgsz=512)  # train the
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 29.6M/29.6M [00:00<00:00, 36.3MB/s]
# New https://pypi.org/project/ultralytics/8.3.163 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
p_yolo5 = 0.903
r_yolo5 = 0.876
mAP_yolo5 = 0.914

storeResults('Yolo v5',p_yolo5,r_yolo5,mAP_yolo5)

# %%
# dislaying metrics for train data
from IPython.display import Image
from IPython.display import display
x = Image(filename='runs/detect/train/F1_curve.png')
y = Image(filename='runs/detect/train/PR_curve.png')
z = Image(filename='runs/detect/train/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # YoloV8

# %%
cd /mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor
# Out:
# /mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor

# %%
# !mkdir v8
# Out:
# mkdir: cannot create directory ‘v8’: File exists

# %%
cd v8
# Out:
# /mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/v8

# %%
# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/yolo/data.yaml", epochs=100, imgsz=512)  # train the
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 64.3MB/s]
# New https://pypi.org/project/ultralytics/8.3.163 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.6 🚀 Python-3.10.9 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
p_yolo8 = 0.914
r_yolo8 = 0.886
mAP_yolo8 = 0.934

storeResults('Yolo v8',p_yolo8,r_yolo8,mAP_yolo8)

# %%
x = Image(filename='runs/detect/train/F1_curve.png')
y = Image(filename='runs/detect/train/PR_curve.png')
z = Image(filename='runs/detect/train/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # Yolov7

# %%
cd /mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor
# Out:
# /mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor

# %%
# !mkdir v7

# %%
cd v7
# Out:
# /mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/v7

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 13.09 MiB/s, done.
# Resolving deltas: 100% (511/511), done.
# Updating files: 100% (108/108), done.

# %%
cd yolov7/
# Out:
# /mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/v7/yolov7

# %%
# Remove cache files (safe to delete)
# !find "/mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/yolo" -name "*.cache" -type f -delete

# %%
# !find "/mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/yolo" -name "*.cache"

# %%
import subprocess

subprocess.run([
    "python", "train.py",
    "--weights", "yolov7.pt",
    "--cfg", "cfg/training/yolov7.yaml",
    "--data", "/mnt/c/Users/TruProjects/Desktop/Projects/projects/july25/brain tumor/yolo/data.yaml",
    "--epochs", "100",
    "--batch-size", "8",
    "--img-size", "512",
    "--name", "yolov7_custom"
])
# Out:
# /home/truprojects/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# YOLOR 🚀 2025-7-10 torch 2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24563.5MB)
#
# ...

# %%
p_yolo7 = 0.805
r_yolo7 = 0.764
mAP_yolo7 = 0.821

storeResults('Yolo v7',p_yolo7,r_yolo7,mAP_yolo7)

# %%
x = Image(filename='runs/train/yolov7_custom3/F1_curve.png')
y = Image(filename='runs/train/yolov7_custom3/PR_curve.png')
z = Image(filename='runs/train/yolov7_custom3/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # Comparison

# %%
#creating dataframe
import pandas as pd
result = pd.DataFrame({ 'ML Model' : ML_Model,

                       'Precision': precision,
                       'Recall'   : recall,
                       'mAP' : mAP,


                      })

# %%
result
# Out:
#   ML Model  Precision  Recall    mAP
# 0  Yolo v5      0.903   0.876  0.914
# 1  Yolo v8      0.914   0.886  0.934
# 2  Yolo v7      0.805   0.764  0.821

# %% [markdown]
# # Graph

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a different palette for each metric
palettes = {
    'Precision': 'Dark2',
    'Recall': 'pink',
    'mAP': 'Blues'
}

for metric in ['Precision', 'Recall', 'mAP']:
    plt.figure(figsize=(8, 4))
    sns.barplot(data=result, x='ML Model', y=metric, palette=palettes[metric])
    plt.title(f'{metric} by Model')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
